# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
fao_data = "Resources/faostat.csv"
obesity_data = "Resources/obesity.csv"

# %%
fao_df = pd.read_csv(fao_data)
obesity_df = pd.read_csv(obesity_data)

# %%
fao_sort = fao_df[["Country", "Item", "Year", "Value" ]]

# %%
obesity_sort = obesity_df[["Country", "Year", "Obesity (%)", "Sex" ]]

# %%
fao_sort
# Out:
#            Country                     Item  Year        Value
# 0      Afghanistan              Animal fats  1975     28559.00
# 1      Afghanistan              Animal fats  1976     31347.00
# 2      Afghanistan              Animal fats  1977     30698.00
# 3      Afghanistan              Animal fats  1978     31009.00
# 4      Afghanistan              Animal fats  1979     31415.00
# ...            ...                      ...   ...          ...
# 25859        China  Milk - Excluding Butter  2009  40847443.77
# 25860        China  Milk - Excluding Butter  2010  43032137.89
# 25861        China  Milk - Excluding Butter  2011  44112511.19
# 25862        China  Milk - Excluding Butter  2012  46460541.62
# 25863        China  Milk - Excluding Butter  2013  47009195.55
#
# [25864 rows x 4 columns]

# %%
category_df = pd.get_dummies(fao_sort.Item)

# %%
category_df['Animal fats'] = category_df['Animal fats']*fao_sort.Value

# %%
category_df['Fish, Seafood'] = category_df['Fish, Seafood']*fao_sort.Value

# %%
category_df['Milk - Excluding Butter'] = category_df['Milk - Excluding Butter']*fao_sort.Value

# %%
category_df['Meat'] = category_df['Meat']*fao_sort.Value

# %%
category_df
# Out:
#        Animal fats  Fish, Seafood  Meat  Milk - Excluding Butter
# 0          28559.0            0.0   0.0                     0.00
# 1          31347.0            0.0   0.0                     0.00
# 2          30698.0            0.0   0.0                     0.00
# 3          31009.0            0.0   0.0                     0.00
# 4          31415.0            0.0   0.0                     0.00
# ...            ...            ...   ...                      ...
# 25859          0.0            0.0   0.0              40847443.77
# 25860          0.0            0.0   0.0              43032137.89
# 25861          0.0            0.0   0.0              44112511.19
# 25862          0.0            0.0   0.0              46460541.62
# 25863          0.0            0.0   0.0              47009195.55
#
# [25864 rows x 4 columns]

# %%
concat_result = pd.concat([fao_sort, category_df], axis = 1)

# %%
concat_result
# Out:
#            Country                     Item  Year        Value  Animal fats  \
# 0      Afghanistan              Animal fats  1975     28559.00      28559.0
# 1      Afghanistan              Animal fats  1976     31347.00      31347.0
# 2      Afghanistan              Animal fats  1977     30698.00      30698.0
# 3      Afghanistan              Animal fats  1978     31009.00      31009.0
# 4      Afghanistan              Animal fats  1979     31415.00      31415.0
# ...            ...                      ...   ...          ...          ...
# 25859        China  Milk - Excluding Butter  2009  40847443.77          0.0
# 25860        China  Milk - Excluding Butter  2010  43032137.89          0.0
# 25861        China  Milk - Excluding Butter  2011  44112511.19          0.0
# 25862        China  Milk - Excluding Butter  2012  46460541.62          0.0
# 25863        China  Milk - Excluding Butter  2013  47009195.55          0.0
#
#        Fish, Seafood  Meat  Milk - Excluding Butter
# 0                0.0   0.0                     0.00
# 1                0.0   0.0                     0.00
# 2                0.0   0.0                     0.00
# 3                0.0   0.0                     0.00
# 4                0.0   0.0                     0.00
# ...              ...   ...                      ...
# 25859            0.0   0.0              40847443.77
# 25860            0.0   0.0              43032137.89
# 25861            0.0   0.0              44112511.19
# 25862            0.0   0.0              46460541.62
# 25863            0.0   0.0              47009195.55
#
# [25864 rows x 8 columns]

# %%
concat_result.loc[(concat_result["Country"] == "Afghanistan") & (concat_result["Year"] == 1975)]
# Out:
#          Country                     Item  Year     Value  Animal fats  \
# 0    Afghanistan              Animal fats  1975   28559.0      28559.0
# 39   Afghanistan            Fish, Seafood  1975     660.0          0.0
# 78   Afghanistan                     Meat  1975  197928.0          0.0
# 117  Afghanistan  Milk - Excluding Butter  1975  777020.5          0.0
#
#      Fish, Seafood      Meat  Milk - Excluding Butter
# 0              0.0       0.0                      0.0
# 39           660.0       0.0                      0.0
# 78             0.0  197928.0                      0.0
# 117            0.0       0.0                 777020.5

# %%
group_concat_result = concat_result.groupby(['Country','Year']).sum()

# %%
group_concat_result = group_concat_result.reset_index()

# %%
group_fin = group_concat_result.drop(columns="Value")

# %%
group_fin.loc[(group_fin["Country"] == "China") & (group_fin["Year"] == 1989)]
# Out:
#      Country  Year  Animal fats  Fish, Seafood         Meat  \
# 1194   China  1989   1320395.17    12617563.93  27702060.34
#
#       Milk - Excluding Butter
# 1194               6381138.31

# %%
group_concat_result.loc[(group_concat_result["Country"] == "China") & (group_concat_result["Year"] == 1989)]
# Out:
#      Country  Year        Value  Animal fats  Fish, Seafood         Meat  \
# 1194   China  1989  48021157.75   1320395.17    12617563.93  27702060.34
#
#       Milk - Excluding Butter
# 1194               6381138.31

# %%
group_fin
# Out:
#           Country  Year  Animal fats  Fish, Seafood       Meat  \
# 0     Afghanistan  1975     28559.00         660.00  197928.00
# 1     Afghanistan  1976     31347.00         770.00  222428.00
# 2     Afghanistan  1977     30698.00         770.00  228988.00
# 3     Afghanistan  1978     31009.00         770.00  234460.00
# 4     Afghanistan  1979     31415.00         770.00  234718.00
# ...           ...   ...          ...            ...        ...
# 6461     Zimbabwe  2009     30533.17       17538.31  265112.63
# 6462     Zimbabwe  2010     29862.17       29130.28  262329.40
# 6463     Zimbabwe  2011     25324.32       39911.35  277321.25
# 6464     Zimbabwe  2012     25767.32       39911.35  280034.49
# 6465     Zimbabwe  2013     20224.56       39911.35  258115.92
#
#       Milk - Excluding Butter
# 0                   777020.50
# 1                   799609.15
# 2                   734533.40
# 3                   745677.02
# 4                   754000.11
# ...                       ...
# 6461                384771.32
# 6462                417734.30
# 6463                456966.87
# 6464                426430.11
# 6465                451443.03
#
# [6466 rows x 6 columns]

# %%
obesity_sort.head(20)
# Out:
#         Country  Year    Obesity (%)         Sex
# 0   Afghanistan  1975  0.5 [0.2-1.1]  Both sexes
# 1   Afghanistan  1975  0.2 [0.0-0.6]        Male
# 2   Afghanistan  1975  0.8 [0.2-2.0]      Female
# 3   Afghanistan  1976  0.5 [0.2-1.1]  Both sexes
# 4   Afghanistan  1976  0.2 [0.0-0.7]        Male
# 5   Afghanistan  1976  0.8 [0.2-2.0]      Female
# 6   Afghanistan  1977  0.6 [0.2-1.2]  Both sexes
# 7   Afghanistan  1977  0.2 [0.0-0.7]        Male
# 8   Afghanistan  1977  0.9 [0.3-2.1]      Female
# 9   Afghanistan  1978  0.6 [0.2-1.3]  Both sexes
# 10  Afghanistan  1978  0.2 [0.1-0.7]        Male
# 11  Afghanistan  1978  0.9 [0.3-2.2]      Female
# 12  Afghanistan  1979  0.6 [0.3-1.3]  Both sexes
# 13  Afghanistan  1979  0.3 [0.1-0.8]        Male
# 14  Afghanistan  1979  1.0 [0.3-2.3]      Female
# 15  Afghanistan  1980  0.7 [0.3-1.4]  Both sexes
# 16  Afghanistan  1980  0.3 [0.1-0.8]        Male
# 17  Afghanistan  1980  1.1 [0.4-2.4]      Female
# 18  Afghanistan  1981  0.7 [0.3-1.4]  Both sexes
# 19  Afghanistan  1981  0.3 [0.1-0.8]        Male

# %%
obesity_sort['Obesity Ratio'] = obesity_sort['Obesity (%)'].str.split(' ', expand=True)[0]
obesity_sort['Obesity Ratio'] = pd.to_numeric(obesity_sort['Obesity Ratio'], errors='coerce')

obesity_sort
# Out:
#            Country  Year       Obesity (%)         Sex  Obesity Ratio
# 0      Afghanistan  1975     0.5 [0.2-1.1]  Both sexes            0.5
# 1      Afghanistan  1975     0.2 [0.0-0.6]        Male            0.2
# 2      Afghanistan  1975     0.8 [0.2-2.0]      Female            0.8
# 3      Afghanistan  1976     0.5 [0.2-1.1]  Both sexes            0.5
# 4      Afghanistan  1976     0.2 [0.0-0.7]        Male            0.2
# ...            ...   ...               ...         ...            ...
# 24565     Zimbabwe  2015     4.5 [2.4-7.6]        Male            4.5
# 24566     Zimbabwe  2015  24.8 [18.9-31.3]      Female           24.8
# 24567     Zimbabwe  2016  15.5 [12.0-19.2]  Both sexes           15.5
# 24568     Zimbabwe  2016     4.7 [2.5-8.0]        Male            4.7
# 24569     Zimbabwe  2016  25.3 [19.1-32.0]      Female           25.3
#
# [24570 rows x 5 columns]

# %%
obesity_category_df = pd.get_dummies(obesity_sort['Sex'])
obesity_category_df
# Out:
#        Both sexes  Female  Male
# 0               1       0     0
# 1               0       0     1
# 2               0       1     0
# 3               1       0     0
# 4               0       0     1
# ...           ...     ...   ...
# 24565           0       0     1
# 24566           0       1     0
# 24567           1       0     0
# 24568           0       0     1
# 24569           0       1     0
#
# [24570 rows x 3 columns]

# %%
obesity_category_df['Both sexes'] = obesity_category_df['Both sexes']*obesity_sort['Obesity Ratio']
obesity_category_df
# Out:
#        Both sexes  Female  Male
# 0            0.25       0     0
# 1            0.00       0     1
# 2            0.00       1     0
# 3            0.25       0     0
# 4            0.00       0     1
# ...           ...     ...   ...
# 24565        0.00       0     1
# 24566        0.00       1     0
# 24567      240.25       0     0
# 24568        0.00       0     1
# 24569        0.00       1     0
#
# [24570 rows x 3 columns]

# %%
obesity_category_df['Female'] = obesity_category_df['Female']*obesity_sort['Obesity Ratio']
obesity_category_df
# Out:
#        Both sexes  Female  Male
# 0            0.25     0.0     0
# 1            0.00     0.0     1
# 2            0.00     0.8     0
# 3            0.25     0.0     0
# 4            0.00     0.0     1
# ...           ...     ...   ...
# 24565        0.00     0.0     1
# 24566        0.00    24.8     0
# 24567      240.25     0.0     0
# 24568        0.00     0.0     1
# 24569        0.00    25.3     0
#
# [24570 rows x 3 columns]

# %%
obesity_category_df['Male'] = obesity_category_df['Male']*obesity_sort['Obesity Ratio']
obesity_category_df
# Out:
#        Both sexes  Female  Male
# 0            0.25     0.0   0.0
# 1            0.00     0.0   0.2
# 2            0.00     0.8   0.0
# 3            0.25     0.0   0.0
# 4            0.00     0.0   0.2
# ...           ...     ...   ...
# 24565        0.00     0.0   4.5
# 24566        0.00    24.8   0.0
# 24567      240.25     0.0   0.0
# 24568        0.00     0.0   4.7
# 24569        0.00    25.3   0.0
#
# [24570 rows x 3 columns]

# %%
concat_result_obesity = pd.concat([obesity_sort, obesity_category_df], axis = 1)
concat_result_obesity
# Out:
#            Country  Year       Obesity (%)         Sex  Obesity Ratio  \
# 0      Afghanistan  1975     0.5 [0.2-1.1]  Both sexes            0.5
# 1      Afghanistan  1975     0.2 [0.0-0.6]        Male            0.2
# 2      Afghanistan  1975     0.8 [0.2-2.0]      Female            0.8
# 3      Afghanistan  1976     0.5 [0.2-1.1]  Both sexes            0.5
# 4      Afghanistan  1976     0.2 [0.0-0.7]        Male            0.2
# ...            ...   ...               ...         ...            ...
# 24565     Zimbabwe  2015     4.5 [2.4-7.6]        Male            4.5
# 24566     Zimbabwe  2015  24.8 [18.9-31.3]      Female           24.8
# 24567     Zimbabwe  2016  15.5 [12.0-19.2]  Both sexes           15.5
# 24568     Zimbabwe  2016     4.7 [2.5-8.0]        Male            4.7
# 24569     Zimbabwe  2016  25.3 [19.1-32.0]      Female           25.3
#
#        Both sexes  Female  Male
# 0            0.25     0.0   0.0
# 1            0.00     0.0   0.2
# 2            0.00     0.8   0.0
# 3            0.25     0.0   0.0
# 4            0.00     0.0   0.2
# ...           ...     ...   ...
# 24565        0.00     0.0   4.5
# 24566        0.00    24.8   0.0
# 24567      240.25     0.0   0.0
# 24568        0.00     0.0   4.7
# 24569        0.00    25.3   0.0
#
# [24570 rows x 8 columns]

# %%
group_concat_result_obesity = concat_result_obesity.groupby(['Country','Year']).sum()
obesity_fin = group_concat_result_obesity.reset_index()

# %%
obesity_fin
# Out:
#           Country  Year  Obesity Ratio  Both sexes  Female  Male
# 0     Afghanistan  1975            1.5        0.25     0.8   0.2
# 1     Afghanistan  1976            1.5        0.25     0.8   0.2
# 2     Afghanistan  1977            1.7        0.36     0.9   0.2
# 3     Afghanistan  1978            1.7        0.36     0.9   0.2
# 4     Afghanistan  1979            1.9        0.36     1.0   0.3
# ...           ...   ...            ...         ...     ...   ...
# 8185     Zimbabwe  2012           41.8      204.49    23.5   4.0
# 8186     Zimbabwe  2013           42.7      213.16    23.9   4.2
# 8187     Zimbabwe  2014           43.7      222.01    24.4   4.4
# 8188     Zimbabwe  2015           44.5      231.04    24.8   4.5
# 8189     Zimbabwe  2016           45.5      240.25    25.3   4.7
#
# [8190 rows x 6 columns]

# %%
group_fin
# Out:
#           Country  Year  Animal fats  Fish, Seafood       Meat  \
# 0     Afghanistan  1975     28559.00         660.00  197928.00
# 1     Afghanistan  1976     31347.00         770.00  222428.00
# 2     Afghanistan  1977     30698.00         770.00  228988.00
# 3     Afghanistan  1978     31009.00         770.00  234460.00
# 4     Afghanistan  1979     31415.00         770.00  234718.00
# ...           ...   ...          ...            ...        ...
# 6461     Zimbabwe  2009     30533.17       17538.31  265112.63
# 6462     Zimbabwe  2010     29862.17       29130.28  262329.40
# 6463     Zimbabwe  2011     25324.32       39911.35  277321.25
# 6464     Zimbabwe  2012     25767.32       39911.35  280034.49
# 6465     Zimbabwe  2013     20224.56       39911.35  258115.92
#
#       Milk - Excluding Butter
# 0                   777020.50
# 1                   799609.15
# 2                   734533.40
# 3                   745677.02
# 4                   754000.11
# ...                       ...
# 6461                384771.32
# 6462                417734.30
# 6463                456966.87
# 6464                426430.11
# 6465                451443.03
#
# [6466 rows x 6 columns]

# %%
merged_data = pd.merge(group_fin, obesity_fin, how = 'inner', left_index = True, right_index=True)
merged_data
# Out:
#         Country_x  Year_x  Animal fats  Fish, Seafood       Meat  \
# 0     Afghanistan    1975     28559.00         660.00  197928.00
# 1     Afghanistan    1976     31347.00         770.00  222428.00
# 2     Afghanistan    1977     30698.00         770.00  228988.00
# 3     Afghanistan    1978     31009.00         770.00  234460.00
# 4     Afghanistan    1979     31415.00         770.00  234718.00
# ...           ...     ...          ...            ...        ...
# 6461     Zimbabwe    2009     30533.17       17538.31  265112.63
# 6462     Zimbabwe    2010     29862.17       29130.28  262329.40
# 6463     Zimbabwe    2011     25324.32       39911.35  277321.25
# 6464     Zimbabwe    2012     25767.32       39911.35  280034.49
# 6465     Zimbabwe    2013     20224.56       39911.35  258115.92
#
#       Milk - Excluding Butter    Country_y  Year_y  Obesity Ratio  Both sexes  \
# 0                   777020.50  Afghanistan    1975            1.5        0.25
# 1                   799609.15  Afghanistan    1976            1.5        0.25
# 2                   734533.40  Afghanistan    1977            1.7        0.36
# 3                   745677.02  Afghanistan    1978            1.7        0.36
# 4                   754000.11  Afghanistan    1979            1.9        0.36
# ...                       ...          ...     ...            ...         ...
# 6461                384771.32       Serbia    2010           57.4      368.64
# 6462                417734.30       Serbia    2011           58.5      384.16
# 6463                456966.87       Serbia    2012           59.7      400.00
# 6464                426430.11       Serbia    2013           60.8      412.09
# 6465                451443.03       Serbia    2014           62.0      428.49
#
#       Female  Male
# 0        0.8   0.2
# 1        0.8   0.2
# 2        0.9   0.2
# 3        0.9   0.2
# 4        1.0   0.3
# ...      ...   ...
# 6461    20.0  18.2
# 6462    20.3  18.6
# 6463    20.6  19.1
# 6464    20.9  19.6
# 6465    21.2  20.1
#
# [6466 rows x 12 columns]

# %%
merged_data = merged_data.drop(columns="Country_y")

# %%
merged_data = merged_data.drop(columns="Year_y")

# %%
merged_data
# Out:
#         Country_x  Year_x  Animal fats  Fish, Seafood       Meat  \
# 0     Afghanistan    1975     28559.00         660.00  197928.00
# 1     Afghanistan    1976     31347.00         770.00  222428.00
# 2     Afghanistan    1977     30698.00         770.00  228988.00
# 3     Afghanistan    1978     31009.00         770.00  234460.00
# 4     Afghanistan    1979     31415.00         770.00  234718.00
# ...           ...     ...          ...            ...        ...
# 6461     Zimbabwe    2009     30533.17       17538.31  265112.63
# 6462     Zimbabwe    2010     29862.17       29130.28  262329.40
# 6463     Zimbabwe    2011     25324.32       39911.35  277321.25
# 6464     Zimbabwe    2012     25767.32       39911.35  280034.49
# 6465     Zimbabwe    2013     20224.56       39911.35  258115.92
#
#       Milk - Excluding Butter  Obesity Ratio  Both sexes  Female  Male
# 0                   777020.50            1.5        0.25     0.8   0.2
# 1                   799609.15            1.5        0.25     0.8   0.2
# 2                   734533.40            1.7        0.36     0.9   0.2
# 3                   745677.02            1.7        0.36     0.9   0.2
# 4                   754000.11            1.9        0.36     1.0   0.3
# ...                       ...            ...         ...     ...   ...
# 6461                384771.32           57.4      368.64    20.0  18.2
# 6462                417734.30           58.5      384.16    20.3  18.6
# 6463                456966.87           59.7      400.00    20.6  19.1
# 6464                426430.11           60.8      412.09    20.9  19.6
# 6465                451443.03           62.0      428.49    21.2  20.1
#
# [6466 rows x 10 columns]

# %%
df.rename(columns={"A": "a", "B": "c"})

# %%
merged_data = merged_data.rename(columns={"Country_x" : "Coutnry", "Year_x" : "Year"})
merged_data
# Out:
#           Coutnry  Year  Animal fats  Fish, Seafood       Meat  \
# 0     Afghanistan  1975     28559.00         660.00  197928.00
# 1     Afghanistan  1976     31347.00         770.00  222428.00
# 2     Afghanistan  1977     30698.00         770.00  228988.00
# 3     Afghanistan  1978     31009.00         770.00  234460.00
# 4     Afghanistan  1979     31415.00         770.00  234718.00
# ...           ...   ...          ...            ...        ...
# 6461     Zimbabwe  2009     30533.17       17538.31  265112.63
# 6462     Zimbabwe  2010     29862.17       29130.28  262329.40
# 6463     Zimbabwe  2011     25324.32       39911.35  277321.25
# 6464     Zimbabwe  2012     25767.32       39911.35  280034.49
# 6465     Zimbabwe  2013     20224.56       39911.35  258115.92
#
#       Milk - Excluding Butter  Obesity Ratio  Both sexes  Female  Male
# 0                   777020.50            1.5        0.25     0.8   0.2
# 1                   799609.15            1.5        0.25     0.8   0.2
# 2                   734533.40            1.7        0.36     0.9   0.2
# 3                   745677.02            1.7        0.36     0.9   0.2
# 4                   754000.11            1.9        0.36     1.0   0.3
# ...                       ...            ...         ...     ...   ...
# 6461                384771.32           57.4      368.64    20.0  18.2
# 6462                417734.30           58.5      384.16    20.3  18.6
# 6463                456966.87           59.7      400.00    20.6  19.1
# 6464                426430.11           60.8      412.09    20.9  19.6
# 6465                451443.03           62.0      428.49    21.2  20.1
#
# [6466 rows x 10 columns]

# %%
connection_string = "postgres:postgres@localhost:5432/ETL"
engine = create_engine(f'postgresql://{connection_string}')

# %%
 # Confirm tables
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# C:\conda\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# C:\conda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# C:\conda\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# C:\conda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# C:\conda\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# C:\conda\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# C:\conda\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-173-2d97e9123e98> in <module>
#       1 # Confirm tables
# ----> 2 engine.table_names()
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2317         """
#    2318
# -> 2319         with self._optional_conn_ctx_manager(connection) as conn:
#    2320             return self.dialect.get_table_names(conn, schema)
#    2321
#
# C:\conda\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2087     def _optional_conn_ctx_manager(self, connection=None):
#    2088         if connection is None:
# -> 2089             with self._contextual_connect() as conn:
#    2090                 yield conn
#    2091         else:
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2303         return self._connection_cls(
#    2304             self,
# -> 2305             self._wrap_pool_connect(self.pool.connect, None),
#    2306             close_with_result=close_with_result,
#    2307             **kwargs
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
# -> 2342                 Connection._handle_dbapi_exception_noconnection(
#    2343                     e, dialect, self
#    2344                 )
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1582             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1583         elif should_wrap:
# -> 1584             util.raise_(
#    1585                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1586             )
#
# C:\conda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         dialect = self.dialect
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# C:\conda\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# C:\conda\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# C:\conda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\conda\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# C:\conda\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# C:\conda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# C:\conda\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# C:\conda\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# C:\conda\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
['Coutnry', 'Year', 'Animal fats', 'Fish, Seafood', 'Meat', 'Milk - Excluding Butter', 'Obesity Ratio', 'Both sexes', 'Female', 'Male']

# %% [markdown]
# #  Load DataFrames into database

# %%
merged_data.to_sql(name='Country', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# C:\conda\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# C:\conda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# C:\conda\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# C:\conda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# C:\conda\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# C:\conda\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# C:\conda\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-174-b10f45243ab9> in <module>
# ----> 1 merged_data.to_sql(name='Country', con=engine, if_exists='append', index=True)
#
# C:\conda\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2651         from pandas.io import sql
#    2652
# -> 2653         sql.to_sql(
#    2654             self,
#    2655             name,
#
# C:\conda\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     510         )
#     511
# --> 512     pandas_sql.to_sql(
#     513         frame,
#     514         name,
#
# C:\conda\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1314             dtype=dtype,
#    1315         )
# -> 1316         table.create()
#    1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#
# C:\conda\lib\site-packages\pandas\io\sql.py in create(self)
#     642
#     643     def create(self):
# --> 644         if self.exists():
#     645             if self.if_exists == "fail":
#     646                 raise ValueError(f"Table '{self.name}' already exists.")
#
# C:\conda\lib\site-packages\pandas\io\sql.py in exists(self)
#     629
#     630     def exists(self):
# --> 631         return self.pd_sql.has_table(self.name, self.schema)
#     632
#     633     def sql_schema(self):
#
# C:\conda\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1338
#    1339     def has_table(self, name, schema=None):
# -> 1340         return self.connectable.run_callable(
#    1341             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1342         )
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2212
#    2213         """
# -> 2214         with self._contextual_connect() as conn:
#    2215             return conn.run_callable(callable_, *args, **kwargs)
#    2216
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2303         return self._connection_cls(
#    2304             self,
# -> 2305             self._wrap_pool_connect(self.pool.connect, None),
#    2306             close_with_result=close_with_result,
#    2307             **kwargs
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
# -> 2342                 Connection._handle_dbapi_exception_noconnection(
#    2343                     e, dialect, self
#    2344                 )
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1582             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1583         elif should_wrap:
# -> 1584             util.raise_(
#    1585                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1586             )
#
# C:\conda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         dialect = self.dialect
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# C:\conda\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# C:\conda\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# C:\conda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\conda\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# C:\conda\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# C:\conda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# C:\conda\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# C:\conda\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# C:\conda\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
merged_data.to_sql(name='Year', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# C:\conda\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# C:\conda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# C:\conda\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# C:\conda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# C:\conda\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# C:\conda\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# C:\conda\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-175-c7c3049f16b4> in <module>
# ----> 1 merged_data.to_sql(name='Year', con=engine, if_exists='append', index=True)
#
# C:\conda\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2651         from pandas.io import sql
#    2652
# -> 2653         sql.to_sql(
#    2654             self,
#    2655             name,
#
# C:\conda\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     510         )
#     511
# --> 512     pandas_sql.to_sql(
#     513         frame,
#     514         name,
#
# C:\conda\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1314             dtype=dtype,
#    1315         )
# -> 1316         table.create()
#    1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#
# C:\conda\lib\site-packages\pandas\io\sql.py in create(self)
#     642
#     643     def create(self):
# --> 644         if self.exists():
#     645             if self.if_exists == "fail":
#     646                 raise ValueError(f"Table '{self.name}' already exists.")
#
# C:\conda\lib\site-packages\pandas\io\sql.py in exists(self)
#     629
#     630     def exists(self):
# --> 631         return self.pd_sql.has_table(self.name, self.schema)
#     632
#     633     def sql_schema(self):
#
# C:\conda\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1338
#    1339     def has_table(self, name, schema=None):
# -> 1340         return self.connectable.run_callable(
#    1341             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1342         )
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2212
#    2213         """
# -> 2214         with self._contextual_connect() as conn:
#    2215             return conn.run_callable(callable_, *args, **kwargs)
#    2216
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2303         return self._connection_cls(
#    2304             self,
# -> 2305             self._wrap_pool_connect(self.pool.connect, None),
#    2306             close_with_result=close_with_result,
#    2307             **kwargs
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
# -> 2342                 Connection._handle_dbapi_exception_noconnection(
#    2343                     e, dialect, self
#    2344                 )
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1582             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1583         elif should_wrap:
# -> 1584             util.raise_(
#    1585                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1586             )
#
# C:\conda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\conda\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         dialect = self.dialect
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# C:\conda\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# C:\conda\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# C:\conda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\conda\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# C:\conda\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# C:\conda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# C:\conda\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# C:\conda\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# C:\conda\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# C:\conda\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
merged_data.to_sql(name='Animal fats', con=engine, if_exists='append', index=True)

# %%
merged_data.to_sql(name='Fish, Seafood', con=engine, if_exists='append', index=True)

# %%
merged_data.to_sql(name='Meat', con=engine, if_exists='append', index=True)

# %%
merged_data.to_sql(name='Milk - Excluding Butter', con=engine, if_exists='append', index=True)

# %%
merged_data.to_sql(name='Obesity Ratio', con=engine, if_exists='append', index=True)

# %%
merged_data.to_sql(name='Both sexes', con=engine, if_exists='append', index=True)

# %%
merged_data.to_sql(name='Female', con=engine, if_exists='append', index=True)

# %%
merged_data.to_sql(name='Male', con=engine, if_exists='append', index=True)
